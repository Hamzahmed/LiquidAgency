# %%
import json
import random
import requests
import string
import requests
import pandas as pd
from googleapiclient.discovery import build
from csv import writer
from urllib.parse import urlparse, parse_qs
from tqdm import tqdm
from youtube_transcript_api import YouTubeTranscriptApi
import numpy as np

# %%
api_key = 'AIzaSyBWXSUTI6F9EEO_rcKvZJmwULo7riQ3Uy4'

HEADER = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'}
youtube= build('youtube', 'v3', developerKey= api_key)

# %%
def generate_transcript(id):
	transcript = YouTubeTranscriptApi.get_transcript(id)
	script = ""

	for text in transcript:
		t = text["text"]
		if t != '[Music]':
			script += t + " "
		
	return script

# %%
# query = 'Knife Reviews'


# query_results = youtube.search().list(
#         part = 'snippet',
#         q = query,
#         order = 'relevance', # You can consider using viewCount
#         maxResults = 20,
#         type = 'video', # Channels might appear in search results
#         relevanceLanguage = 'en',
#         safeSearch = 'moderate',
#         ).execute()

# %%
video_id = ["2_g-SdpHEWY",
"qdbNejPUtUQ", "FUufroRWvfc", "GEYcxRvLw3g","Tfcu-GoZBeA" ,"ZhyJj8XMnPY" ,"54YumGPjO7Q","cQOVB5UrOjc","8EYNe-Trgqs","5JXBoex_Q9A",
"TMPdGMmD9OU","YcpLLAbyMqI","GSejQk4gFcc", "rYtJ761bpeM", "wSEShsuvA4A","-zM99Xmedwo","_kSc_AL2YV4","7V7Ik-shXFY","DNrf7_RXW7k"]

# %%
video_id
# Out:
# ['2_g-SdpHEWY',
#  'qdbNejPUtUQ',
#  'FUufroRWvfc',
#  'GEYcxRvLw3g',
#  'Tfcu-GoZBeA',
#  'ZhyJj8XMnPY',
#  '54YumGPjO7Q',
#  'cQOVB5UrOjc',
#  '8EYNe-Trgqs',
#  '5JXBoex_Q9A',
#  'TMPdGMmD9OU',
#  'YcpLLAbyMqI',
#  'GSejQk4gFcc',
#  'rYtJ761bpeM',
#  'wSEShsuvA4A',
#  '-zM99Xmedwo',
#  '_kSc_AL2YV4',
#  '7V7Ik-shXFY',
#  'DNrf7_RXW7k']

# %%
len(video_id)
# Out:
# 19

# %%
for i, video in enumerate(tqdm(video_id, ncols = 100)):
    response = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=video_id
    ).execute()
    video_title_temp = []
    video_desc_temp = []
    channel_temp = []
    video_tags_temp = []
    like_count_temp = []
    video_length_temp_temp = []
    
    for item in response['items']:
        video_title_temp.append(item['snippet']['title'])
        video_desc_temp.append(item['snippet']['description'])
        channel_temp.append(item['snippet']['channelTitle'])
        video_tags_temp.append(item['snippet']['tags'])
        like_count_temp.append(item['statistics']['likeCount'])
        video_length_temp_temp.append(item['contentDetails']['duration'])
# Out:
# 100%|███████████████████████████████████████████████████████████████| 19/19 [00:03<00:00,  6.05it/s]

# %%
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'zfm244IlbdzMiNmEg8lp0wngqbM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'hfetPsAvMUQT4DOndoSCpF9h6vg',
#    'id': '2_g-SdpHEWY',
#    'snippet': {'publishedAt': '2021-11-19T19:00:10Z',
#     'channelId': 'UCZIIkzJ6XQiNeJkha6Ais5g',
#     'title': '2021 Pocket Knife Holiday Gift Guide! | Knife Banter With Kurt And Dallas',
# ...

# %%
video_title_temp
# Out:
# ['2021 Pocket Knife Holiday Gift Guide! | Knife Banter With Kurt And Dallas',
#  'The Best Kershaw Pocket Knives in 2020 at Blade HQ | Knife Banter S2 (Ep 32)',
#  'The Best Pocket Knives of 2020 | Knife Banter S2 (Ep 55)',
#  'Best CIVIVI Pocket Knives for EDC of 2020 - KnifeCenter',
#  'The BEST One-and-Done EDC Knife',
#  'Best EDC Knives for 5th Pocket Carry of 2021 - Finally Using That Small Pocket on Your Jeans',
#  'Best Keychain Knives of 2021',
#  'Best Knife from Every Brand in 2021, Part 1',
#  'Best Pocket Cleaver Folding Knives of 2020 Available at KnifeCenter',
#  'Best Pocket Fixed Blade EDC Knives in 2021',
#  'The Top 20 BEST Folding Knives of All Time - According to Metal Complex - Updated 2021',
#  'The Best Gentleman’s Knives of 2021',
#  'The 8 Best Pocket Knives for EDC in 2021',
#  'The Best Pocket Knife for (Almost) Everyone',
#  "The Best Tactical Knives: DCA's Faves in 2021",
#  'The Best, Biggest, and Baddest Folding Knives of 2021',
# ...

# %%
video_length_temp_temp
# Out:
# ['PT18M55S',
#  'PT22M14S',
#  'PT37M54S',
#  'PT10M42S',
#  'PT15M57S',
#  'PT17M51S',
#  'PT25M13S',
#  'PT28M7S',
#  'PT12M4S',
#  'PT23M40S',
#  'PT42M',
#  'PT24M40S',
#  'PT6M17S',
#  'PT25M51S',
#  'PT22M10S',
#  'PT28M58S',
#  'PT29M4S',
#  'PT12M26S',
#  'PT15M17S']

# %%
import re

def YTDurationToSeconds(duration):
    match = re.match('PT((\d+)H)?((\d+)M)?((\d+)S)?', duration).groups()
    hours = int(match[1]) if match[1] else 0
    minutes = int(match[3]) if match[3] else 0
    seconds = int(match[5]) if match[5] else 0
    #return f"{hours}:{minutes}:{seconds}"
    return hours * 3600 + minutes * 60 + seconds
video_length_temp2 = []
for x in list(video_length_temp_temp):
    video_length_temp2.append(YTDurationToSeconds(x))
    
# 933

# %%
print(sum(video_length_temp2))
# Out:
# 25160

# %%
transcripts = []
for i in video_id:
    transcripts.append(generate_transcript(i))

# %%
len(transcripts)
# Out:
# 19

# %%
video_title_pop = []
video_desc_pop = []
channel_pop = []
video_tags_pop = []
like_count_pop = []
video_length_pop = []
transcripts_pop = []
video_id_pop = []
# channel_pop = []
# video_title_pop = []
# video_desc_pop = []
comments_pop = []
# comment_id_pop = []
# reply_count_pop = []
# like_count_pop = []
transcripts_pop = []
for i, video in enumerate(tqdm(video_id, ncols = 100)):
    response = youtube.commentThreads().list(
                    part = 'snippet',
                    videoId = video,
                    maxResults = 100, 
                    order = 'relevance', #... ranked on relevance
                    textFormat = 'plainText', 
                    ).execute()
    
    comments_temp = []
    # comment_id_temp = []
    # reply_count_temp = []
    # like_count_temp = []
    for item in response['items']:
        comments_temp.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])
        # comment_id_temp.append(item['snippet']['topLevelComment']['id'])
        # reply_count_temp.append(item['snippet']['totalReplyCount'])
        # like_count_temp.append(item['snippet']['topLevelComment']['snippet']['likeCount'])
    comments_pop.extend(comments_temp)
    # comment_id_pop.extend(comment_id_temp)
    # reply_count_pop.extend(reply_count_temp)
    # like_count_pop.extend(like_count_temp)
    
    video_title_pop.extend([video_title_temp[i]]*len(comments_temp))
    video_desc_pop.extend([video_desc_temp[i]]*len(comments_temp))
    channel_pop.extend([channel_temp[i]]*len(comments_temp))
    video_tags_pop.extend([video_tags_temp[i]]*len(comments_temp))
    like_count_pop.extend([like_count_temp[i]]*len(comments_temp))
    video_length_pop.extend([video_length_temp[i]]*len(comments_temp))
    transcripts_pop.extend([transcripts[i]]*len(comments_temp))
    video_id_pop.extend([video_id[i]]*len(comments_temp))

    
#query_pop = [query] * len(comments_pop)
# Out:
# 100%|███████████████████████████████████████████████████████████████| 19/19 [00:03<00:00,  4.84it/s]

# %%
video_tags_pop = [tuple(x) for x in video_tags_pop]

# %%
len(channel_pop), len(video_title_pop), len(video_desc_pop), len(video_id_pop), len(video_desc_pop), len(transcripts_pop), len(comments_pop)
# Out:
# (1589, 1589, 1589, 1589, 1589, 1589, 1589)

# %%
Youtube_Knife_Reviews = {
        #'Query': query_pop,
        'Channel': channel_pop,
        'Video Title': video_title_pop,
        'Video Description': video_desc_pop,
        'Video Likes': like_count_pop,
        'Video Length': video_length_pop, 
        'Video Tags': video_tags_pop,
        'Video ID': video_id_pop,
        'Video Transcript': transcripts_pop,
        'Comment': comments_pop,
        
        # 'Comment ID': comment_id_temp,
        # 'Replies': reply_count_temp,
        # 'Likes': like_count_temp,
        }

Youtube_Knife_Reviews = pd.DataFrame(Youtube_Knife_Reviews, columns = Youtube_Knife_Reviews.keys())

# %%
Youtube_Knife_Reviews
# Out:
#        Channel                                        Video Title  \
# 0     Blade HQ  2021 Pocket Knife Holiday Gift Guide! | Knife ...
# 1     Blade HQ  2021 Pocket Knife Holiday Gift Guide! | Knife ...
# 2     Blade HQ  2021 Pocket Knife Holiday Gift Guide! | Knife ...
# 3     Blade HQ  2021 Pocket Knife Holiday Gift Guide! | Knife ...
# 4     Blade HQ  2021 Pocket Knife Holiday Gift Guide! | Knife ...
# ...        ...                                                ...
# 1584     USCCA  2021 TOP 7 Kershaw Pocket Knives Review [Kersh...
# 1585     USCCA  2021 TOP 7 Kershaw Pocket Knives Review [Kersh...
# 1586     USCCA  2021 TOP 7 Kershaw Pocket Knives Review [Kersh...
# 1587     USCCA  2021 TOP 7 Kershaw Pocket Knives Review [Kersh...
# 1588     USCCA  2021 TOP 7 Kershaw Pocket Knives Review [Kersh...
#
#                                       Video Description Video Likes  \
# 0     Need a pocket knife as a gift for your loved o...        1136
# ...

# %%
Arrange_Data = Youtube_Knife_Reviews.groupby(['Channel', 'Video Title','Video ID','Video Likes', 'Video Length','Video Description', 'Video Tags','Video Transcript'])['Comment'].agg(lambda x: " ".join(x))

# %%
Final_Data = pd.DataFrame(Arrange_Data)

# %%
Final_Data.to_csv('Youtube_Knife_Reviews.csv')
