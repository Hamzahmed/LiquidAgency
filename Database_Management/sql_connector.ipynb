# %%
import pandas as pd
from sqlalchemy import (create_engine, Float, Text, MetaData, Table, Column, Integer, String, PrimaryKeyConstraint, ForeignKey)
df = pd.read_csv('/Users/hamza.ahmed/Library/Containers/com.microsoft.Excel/Data/Downloads/Benchmade - Sheet2.csv')

# %%
df
# Out:
#      Knife_id                                       Name   Price  \
# 0           1  4010-211 COLLECTORS EDITION STATION KNIFE  1500.0
# 1           2    4000-211 COLLECTORS EDITION 3 PIECE SET  2400.0
# 2           3                         602-211 TENGU TOOL   350.0
# 3           4                         9070BK-1 CLAYMORE™   230.0
# 4           5                           9070BK CLAYMORE™   230.0
# ..        ...                                        ...     ...
# 139       140                                178SBK SOCP   180.0
# 140       141                          SOCP 178SBK-COMBO   360.0
# 141       142                              SOCP 178SBKSN   165.0
# 142       143                       945-221 MINI OSBORNE   700.0
# 143       144                            Phaeton® Family   180.0
#
#      Blade_Length        Blade_Material  Blade_Grind  Blade_Finish
# 0            5.97  Damasteel (58-60HRC)          NaN        Etched
# 1            8.04  Damasteel (58-60HRC)          NaN        Etched
# 2            1.14    CPM-D2 (60-62 HRC)          NaN  Cobalt Black
# 3            3.60    CPM-D2 (60-62 HRC)          NaN  Cobalt Black
# 4            3.60  CPM-S30V (58-60 HRC)          NaN     Stonewash
# ..            ...                   ...          ...           ...
# 139          3.22                   NaN          NaN           NaN
# 140          3.22                   NaN          NaN           NaN
# 141          3.22                   NaN          NaN           NaN
# 142           NaN  Damasteel (58-60HRC)          NaN     Damasteel
# 143           NaN  CPM-S30V (58-60 HRC)          NaN           NaN
#
# [144 rows x 7 columns]

# %%
db_connection= 'postgresql+psycopg2://postgres:DataIsConfusing2022@localhost/sql_demo2'
engine = create_engine(db_connection)
df.to_sql('pandas_db', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/hamza.ahmed/Python Apps/Database_Management/sql_connector.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell:/Users/hamza.ahmed/Python%20Apps/Database_Management/sql_connector.ipynb#ch0000002?line=0'>1</a> db_connection= 'postgresql+psycopg2://postgres:DataIsConfusing2022@localhost/sql_demo2'
#       <a href='vscode-notebook-cell:/Users/hamza.ahmed/Python%20Apps/Database_Management/sql_connector.ipynb#ch0000002?line=1'>2</a> engine = create_engine(db_connection)
# ----> <a href='vscode-notebook-cell:/Users/hamza.ahmed/Python%20Apps/Database_Management/sql_connector.ipynb#ch0000002?line=2'>3</a> df.to_sql('pandas_db', engine)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py:2872, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2733'>2734</a> """
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2734'>2735</a> Write records stored in a DataFrame to a SQL database.
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2735'>2736</a>
#    (...)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2867'>2868</a> [(1,), (None,), (2,)]
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2868'>2869</a> """
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2869'>2870</a> from pandas.io import sql
# -> <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2871'>2872</a> sql.to_sql(
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2872'>2873</a>     self,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2873'>2874</a>     name,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2874'>2875</a>     con,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2875'>2876</a>     schema=schema,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2876'>2877</a>     if_exists=if_exists,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2877'>2878</a>     index=index,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2878'>2879</a>     index_label=index_label,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2879'>2880</a>     chunksize=chunksize,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2880'>2881</a>     dtype=dtype,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2881'>2882</a>     method=method,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py?line=2882'>2883</a> )
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py:717, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=711'>712</a> elif not isinstance(frame, DataFrame):
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=712'>713</a>     raise NotImplementedError(
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=713'>714</a>         "'frame' argument should be either a Series or a DataFrame"
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=714'>715</a>     )
# --> <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=716'>717</a> pandas_sql.to_sql(
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=717'>718</a>     frame,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=718'>719</a>     name,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=719'>720</a>     if_exists=if_exists,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=720'>721</a>     index=index,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=721'>722</a>     index_label=index_label,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=722'>723</a>     schema=schema,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=723'>724</a>     chunksize=chunksize,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=724'>725</a>     dtype=dtype,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=725'>726</a>     method=method,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=726'>727</a>     engine=engine,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=727'>728</a>     **engine_kwargs,
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=728'>729</a> )
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py:1751, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1700'>1701</a> """
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1701'>1702</a> Write records stored in a DataFrame to a SQL database.
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1702'>1703</a>
#    (...)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1746'>1747</a>     Any additional kwargs are passed to the engine.
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1747'>1748</a> """
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1748'>1749</a> sql_engine = get_engine(engine)
# -> <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1750'>1751</a> table = self.prep_table(
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1751'>1752</a>     frame=frame,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1752'>1753</a>     name=name,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1753'>1754</a>     if_exists=if_exists,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1754'>1755</a>     index=index,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1755'>1756</a>     index_label=index_label,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1756'>1757</a>     schema=schema,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1757'>1758</a>     dtype=dtype,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1758'>1759</a> )
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1760'>1761</a> sql_engine.insert_records(
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1761'>1762</a>     table=table,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1762'>1763</a>     con=self.connectable,
#    (...)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1769'>1770</a>     **engine_kwargs,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1770'>1771</a> )
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1772'>1773</a> self.check_case_sensitive(name=name, schema=schema)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py:1650, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1637'>1638</a>             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1639'>1640</a> table = SQLTable(
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1640'>1641</a>     name,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1641'>1642</a>     self,
#    (...)
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1647'>1648</a>     dtype=dtype,
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1648'>1649</a> )
# -> <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1649'>1650</a> table.create()
#    <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=1650'>1651</a> return table
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py:858, in SQLTable.create(self)
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=855'>856</a> if self.exists():
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=856'>857</a>     if self.if_exists == "fail":
# --> <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=857'>858</a>         raise ValueError(f"Table '{self.name}' already exists.")
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=858'>859</a>     elif self.if_exists == "replace":
#     <a href='file:///~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py?line=859'>860</a>         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'pandas_db' already exists.
